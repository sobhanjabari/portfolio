# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# بازاریابی بانکی
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مقدمه
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     بازاریابی یکی از ستون‌های اصلی هر کسب‌و‌کاری است. بازاریابی است که به افزایش سود و گسترش سازمان کمک می‌کند. در بازاریابی سعی می‌کنیم مخاطبان خود را به محصولی که قصد فروشش را داریم جذب کنیم، تا به این گونه فروش را افزایش دهیم.
#     بازاریابی هوشمند، یکی از کاربردهای هوش مصنوعی و یادگیری ماشین در تجارت و کسب‌و‌کار است. یکی از اساس بازاریابی هوشمند را در جمله زیر می‌بینیم.
#     <br>
#     <i>«محصول را به کسانی معرفی کنیم که به احتمال بیشتری خرید انجام می‌دهند.»</i>
#     <br>
#     مجموعه‌داده‌ای که در اختیار داریم، شامل اطلاعات مختلف از مشتریانی است که مخاطب یک کمپین بازاریابی برای سپرده بلندمدت بانکی بوده‌اند.
#     کمپین بازاریابی یا پویش بازاریابی، مجموعه فعالیت‌هایی است که آگاهی مشتریان را نسبت به یک محصول افزایش می‌دهد.
#     <br>
#      در مورد بازاریابی بانکی می‌توان این‌گونه تعریف کرد که متخصصان بازاریابی بانکی، با روش‌های متنوع سعی در افزایش آگاهی مشتریان درمورد خدمات بانکی دارند.
#     در این مسئله نیز ما اطلاعات مختلفی از مشتریان یک بانک را در اختیار داریم. همچنین می‌دانیم نتیجه‌ی کمپین‌های قبلی مارکتینگ برای آن‌ها چگونه بوده است. بنابراین قصد داریم به روش‌های هوشمند پیش‌بینی کنیم کدام مشتر‌ی‌ها، برای سپرده‌‌ی بلندمدتی که تحت کمپین جدید است، اقدام می‌کنند. به عبارت بهتر، می‌خواهیم بدانیم نتیجه‌ی کمپین جدید، برای کدام مشتری موفقیت‌آمیز خواهد بود.
#     از آن جایی که هنوز با مدل‌سازی آشنا نشده‌اید صرفاً از شما می‌خواهیم در پیش‌پردازش داده‌ها به ما کمک کنید. کدهای مرتبط با مدل‌سازی داخل همین نوت‌بوک وجود دارند. شما فقط کافیست آن‌ها را اجرا کنید!
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#      مجموعه‌داده‌ای که در این سوال در اختیار داریم، همانطور که پیش‌تر گفته شد، اطلاعات مشتریانی را به دست می‌دهد که تحت کمپین معرفی سپرده بلندمدت بانک، با آن‌ها تماس گرفته شده است. بنابراین هر سطر از مجموعه‌داده، مربوط به یک مشتری است. در جدول زیر، ستون‌های این مجموعه‌داده را بررسی می‌کنیم.
# <br>
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |ستون| توضیحات|
# | :------: | :-------: |
# | <code>age</code> | سن مشتری |
# | <code>job</code> | شغل مشتری |
# | <code>marital</code> | وضعیت تاهل مشتری |
# | <code>education</code> | وضعیت تحصیلی مشتری |
# | <code>default</code> | وضعیت نکول* (عدم پرداخت بدهی) |
# | <code>housing</code> | آیا مشتری وام مسکن گرفته است |
# | <code>loan</code> | آیا مشتری وام شخصی گرفته است |
# | <code>is_telephone_contact</code> | آیا تماس با مشتری از طریق تلفن ثابت بوده است |
# | <code>month</code> | ماهی که آخرین تماس با مشتری گرفته شده است |
# | <code>day_of_week</code> | روزی از هفته که آخرین تماس با مشتری گرفته شده است |
# | <code>duration</code> | مدت زمانی که آخرین تماس با مشتری به طول انجامیده است |
# | <code>campaign</code> | تعداد دفعات تماسی که با همین مشتری در همین کمپین گرفته شده است |
# | <code>pdays</code> | تعداد روزی که از آخرین تماس با مشتری برای کمپین قبلی می‌گذرد. اگر ۹۹۹ باشد، یعنی در کمپین قبلی با این مشتری تماس گرفته نشده است |
# | <code>previous</code> | تعداد تماس‌هایی که تا قبل از این کمپین با این مشتری برقرار شده است |
# | <code>poutcome</code> | نتیجه کمپین قبلی برای این مشتری |
# | <code>y</code> | نتیجه کمپین فعلی برای این مشتری |
#
# *:
# 0: مشتری بدهی خود را به‌موقع پرداخت کرده و نکول نکرده است.
# 1: مشتری در پرداخت بدهی خود نکول کرده است (یعنی قادر به پرداخت اقساط یا بدهی‌های خود نبوده است).
# </font>
# </div>
# <center>
#
# <br>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     بنابراین در مجموع این مجموعه‌داده دارای ۱۶ ستون و ۴۱۱۸۸ سطر است.
#     <br>
#     در این مجموعه‌داده مقادیر گم‌شده با عبارت <code>unknown</code> مشخص شده‌اند. یعنی هر جا کلمه‌ی <code>unknown</code> دیده شد، به منزله‌ی <code>NaN</code> است. پرکردن مقادیر گم‌شده هم بخشی از حل مسئله است که در ادامه کامل‌تر به آن پرداخته‌ایم.
# <br>
# </font>
# </p>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     حال که قرار است در پیش‌پردازش داده به ما کمک کنید، از شما می‌خواهیم مقادیر گسسته و دسته‌ای مجموعه‌داده را مدیریت کنید. برای آن‌که بتوانید مقادیر گسسته را به عدد تبدیل کنید، نیاز است جدول راهنمایی داشته باشید. در زیر ۵ جدول تبدیل آورده شده است که به کمک آن‌ها می‌توانید مدیریت ستون‌های دسته‌ای را بهتر انجام دهید.
# <br>
# </font>
# </p>
#
#
# <center>
# <div style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |مقادیر درون دیتافریم|مقادیری که باید جایگزین بشوند|
# | :---: | :---: |
# |<code>yes</code>|<code>1</code>|
# |<code>no<code>|<code>0</code>|
#
# <br>
#
# |مقادیر درون دیتافریم|مقادیری که باید جایگزین بشوند|
# | :---: | :---: |
# |<code>illiterate</code>|<code>0</code>|
# |<code dir=ltr>basic.4y</code>|<code>1</code>|
# |<code dir=ltr>basic.6y</code>|<code>2</code>|
# |<code dir=ltr>basic.9y</code>|<code>3</code>|
# |<code dir=ltr>high.school</code>|<code>4</code>|
# |<code dir=ltr>professional.course</code>|<code>5</code>|
# |<code dir=ltr>university.degree</code>|<code>6</code>|
#
# <br>
#
# |مقادیر درون دیتافریم|مقادیری که باید جایگزین بشوند|
# | :---: | :---: |
# |<code>mon</code>|<code>0</code>|
# |<code>tue</code>|<code>1</code>|
# |<code>wed</code>|<code>2</code>|
# |<code>thu</code>|<code>3</code>|
# |<code>fri</code>|<code>4</code>|
# |<code>sat</code>|<code>5</code>|
# |<code>sun</code>|<code>6</code>|
#
# <br>
#
# |مقادیر درون دیتافریم|مقادیری که باید جایگزین بشوند|
# | :---: | :---: |
# |<code>jan</code>|<code>0</code>|
# |<code>feb</code>|<code>1</code>|
# |<code>mar</code>|<code>2</code>|
# |<code>apr</code>|<code>3</code>|
# |<code>may</code>|<code>4</code>|
# |<code>jun</code>|<code>5</code>|
# |<code>jul</code>|<code>6</code>|
# |<code>aug</code>|<code>7</code>|
# |<code>sep</code>|<code>8</code>|
# |<code>oct</code>|<code>9</code>|
# |<code>nov</code>|<code>10</code>|
# |<code>dec</code>|<code>11</code>|
#
# <br>
#
# |مقادیر درون دیتافریم|مقادیری که باید جایگزین بشوند|
# | :---: | :---: |
# |<code>failure</code>|<code dir=ltr>-1</code>|
# |<code>nonexistent</code>|<code dir=ltr>0</code>|
# |<code>success</code>|<code dir=ltr>1</code>|
#
#
# </font>
# </div>
# </center>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     کتابخانه‌های مورد نیاز را وارد کرده و مجموعه‌داده را بخوانید.
# <br>
# </font>
# </p>

# %%
# !pip install jupyter==1.1.1 jupyterlab==4.3.6 flaml==2.3.4 xgboost==3.0.0 scikit-learn==1.6.1 rbo==0.1.3 numpy==1.26.4 pandas==2.2.3 matplotlib==3.10.1 seaborn==0.13.2 pickle-mixin==1.0.2 joblib==1.4.2 parsivar plotly

# %%
import pandas as pd
from flaml import AutoML
from sklearn.metrics import f1_score

# %%
df = pd.read_csv('bank-additional-full.csv', na_values='unknown')
df.head()

# %%
# شناسایی ستون‌های دسته‌ای (به جز ستون هدف 'y')
categorical_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan',
                   'is_telephone_contact', 'month', 'day_of_week', 'poutcome']

# پر کردن مقادیر گمشده با پرتکرارترین مقدار هر ستون
for col in categorical_cols:
    mode_value = df[col].mode()[0]
    df[col] = df[col].fillna(mode_value)

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     برای آن که ارزش کار خود را درک کنید، می‌توانید ابتدا که هیچ‌گونه پیش‌پردازشی روی داده انجام نشده است، یکبار با داده‌های اصلی مدل‌سازی کرده و عملکرد مدل را مشاهده کنید. با اجرای سلول زیر یک مدل روی داده‌ها آموزش می‌بیند و نتایجی تولید می‌کند. توجه کنید که اجرای این سلول و فرآیند مدل‌سازی ممکن است چند دقیقه‌ای طول بکشد.
#     <br>
#     اگر اجرای این سلول با شکست مواجه شد، می‌تواند به یکی از دلایل زیر باشد.
# </font>
# </p>
#
#
# <div dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     <ul>
#         <li>
#             کتابخانه‌ی Fast Auto ML را نصب نکرده باشید.
#         </li>
#         <li>
#             در بارگیری مجموعه‌داده دچار مشکل شده باشید.
#         </li>
#     </ul>
# </font>
# </div>

# %%
target_variable = 'y'
df_train = df.sample(frac=.7, random_state=313)

model = AutoML(task='classification', time_budget=120, verbose=0, estimator_list=['lgbm', 'rf'])
model.fit(df_train.drop(target_variable, axis=1), df_train[target_variable])

df_test = df.drop(df_train.index)
y_pred = model.predict(df_test.drop(target_variable, axis=1))

f1score = f1_score(df_test[target_variable], y_pred, pos_label='yes')*100
print(f'performance of model is {f1score} %')

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت اول
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# همان‌طور که قبلا گفته شد، در ستون‌های دسته‌ای این دیتافریم، مقادیر گم‌شده وجود دارد. به عنوان قسمت اول از این سوال، از شما می‌خواهیم:
# </font>
# </p>
# <ol dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
#     <li>اسم همه ستون‌های دسته‌ای دیتافریم را درون لیستی به اسم <code>categorical_cols</code> بریزید. متغیر هدف نباید در این لیست قرار گرفته باشد.</li>
#     <li>سپس به ازای همه ستون‌هایی که اسم‌شان در <code>categorical_cols</code> وجود دارد، مقادیر گم‌شده هر ستون را با پر تکرارترین مقدار آن ستون جایگزین کنید. دیتافریمی که هیچ مقدار گم‌شده‌ای ندارد را درون خود دیتافریم <code>df</code> ذخیره کنید. بنابراین بعد از حل قسمت اول، دیتافریم <code>df</code> هیچ مقدار گم‌شده‌ای نباید داشته باشد.</li>
# </ol>

# %%
# TO-DO: fill `categorical_cols` and fill na values in categorical columns of `df` dataframe.
categorical_cols = None
df = None
df.head()

# %%
# شناسایی ستون‌های دسته‌ای (به جز ستون هدف 'y')
categorical_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan',
                   'is_telephone_contact', 'month', 'day_of_week', 'poutcome']

# پر کردن مقادیر گمشده با پرتکرارترین مقدار هر ستون
for col in categorical_cols:
    mode_value = df[col].mode()[0]
    df[col] = df[col].fillna(mode_value)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت دوم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در این قسمت از شما انتظار داریم ۴ لیست آماده کنید. در هر لیست، ستون‌های دیتافریم <code>df</code> به تفکیک نوع‌شان طبقه‌بندی شده‌اند.
#
# <ul dir=rtl>
#     <li>در لیست <code>continuous_cols</code> اسامی ستون‌هایی را بنویسید که مقدار پیوسته دارند.</li>
#     <li>در لیست <code>binary_cols</code> اسامی ستون‌هایی را بنویسید که مقدار گسسته دودویی دارند.</li>
#     <li>در لیست <code>nominal_cols</code> اسامی ستون‌هایی را بنویسید که مقدار اسمی دارند.</li>
#     <li>در لیست <code>ordinal_cols</code> اسامی ستون‌هایی را بنویسید که مقدار ترتیبی دارند.</li>
# </ul>
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# توجه کنید که نوع (<code>dtype</code>) تمام متغیر‌هایی که در بالا معرفی شدند، باید حتما لیست باشد.
# </font>
# </p>

# %%
continuous_cols = None
binary_cols = None
nominal_cols = None
ordinal_cols = None

# %%
# ستون‌های پیوسته
continuous_cols = ['age', 'duration', 'campaign', 'pdays', 'previous']

# ستون‌های دودویی
binary_cols = ['default', 'housing', 'loan', 'is_telephone_contact', 'y']

# ستون‌های اسمی
nominal_cols = ['job', 'marital', 'poutcome']

# ستون‌های ترتیبی
ordinal_cols = ['education', 'month', 'day_of_week']

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت سوم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در قسمت سوم از شما می‌خواهیم دیتافریمی داشته باشید که فقط شامل ستون‌های دودویی دیتافریم <code>df</code> باشد. سپس همه مقادیر دیتافریم جدید را به عدد تبدیل کنید.
# <br>
# با استفاده از <code>binary_cols</code> می‌توانید دیتافریم <code>binary_df</code>  را بسازید.
# در حقیقت دیتافریم <code>binary_df</code> بخشی از دیتافریم <code>df</code> است که فقط شامل ستون‌های دودویی آن باشد. یعنی هیچ ستون دیگری با مقادیر پیوسته، اسمی یا ترتیبی درون دیتافریم <code>binary_df</code> وجود ندارد. توجه کنید که تمام مقادیر این دیتافریم باید عدد باشند (به‌جای <code>yes</code> عدد <code>1</code> و به جای <code>no</code> عدد <code>0</code> قرار دهید).
# </font>
# </p>

# %%
# TO-DO: create `binary_df` and replace all `object` values with numeric ones
binary_df = None
binary_df.head()

# %%
# ایجاد دیتافریم فقط با ستون‌های دودویی
binary_df = df[binary_cols].copy()

# تبدیل مقادیر به عدد
binary_df = binary_df.replace({'yes': 1, 'no': 0})

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت چهارم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در قسمت چهارم از شما می‌خواهیم دیتافریمی داشته باشید که فقط شامل ستون‌های اسمی دیتافریم <code>df</code> باشد.
# <br>
# با استفاده از <code>nominal_cols</code> دیتافریم <code>nominal_df</code>   را بسازید.
# چون در ویژگی‌های اسمی، هیچ ترتیبی وجود ندارد، باید به شکل One-Hot درآیند.
# نحوه‌ی کدگذاری One-Hot ستون‌های گسسته اسمی، باید به شکلی باشد که اسم ستون‌هایی که تشکیل می‌شوند، دارای دو بخش باشد. در بخش اول، <b>اسم ستونی</b> که کدگذاری می‌شود و در بخش دوم اسم <b>مقدار اسمی</b> بیاید، در حالی که این دو بخش با علامت «زیرخط» (<code>_</code>) از هم جدا شده باشند.
# برای درک بهتر، به مثال زیر توجه کنید.
# فرض کنید ستون خیالی به اسم <code>imaginary_col</code> درون مجموعه‌داده وجود می‌داشت که دارای مقادیری از نوع اسمی به شکل زیر بود :
# </font>
# </p>
#
# <center>
# <div style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |<code>imaginary_col</code> |
# | :---: |
# |<code>val1</code>|
# |<code>val1</code>|
# |<code>val2</code>|
# |<code>val3</code>|
# |<code>val2</code>|
# |<code>val1</code>|
# |<code>val3</code>|
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     چیزی که شما باید در نهایت  برای این ستون آماده کنید به شکل زیر خواهد بود:
# </font>
# </p>
#
# <center>
# <div style="line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |<code>imaginary_col_val1</code>|<code>imaginary_col_val2</code>|<code>imaginary_col_val3</code>|
# | :---: | :---: | :---: |
# |<code>1</code>|<code>0</code>|<code>0</code>|
# |<code>1</code>|<code>0</code>|<code>0</code>|
# |<code>0</code>|<code>1</code>|<code>0</code>|
# |<code>0</code>|<code>0</code>|<code>1</code>|
# |<code>0</code>|<code>1</code>|<code>0</code>|
# |<code>1</code>|<code>0</code>|<code>0</code>|
# |<code>0</code>|<code>0</code>|<code>1</code>|
#
# </font>
# </div>
#
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# به ازای هر ستونی از دیتافریم <code>df</code>  که از نوع اسمی است، این کار رو تکرار کنید.
# در نهایت جدول ایجاد شده ناشی از One-Hot کردن هر ستون را به یکدیگر متصل کنید و نتیجه نهایی را درون متغیر <code>nominal_df</code> بریزید.
# توجه داشته باشید که دیتافریم <code>nominal_df</code> به هیچ وجه نباید شامل خود ستون‌هایی باشد که One-Hot شدند. صرفاً درون این دیتافریم، کد شده‌ی ستون‌ها را قرار دهید.
# </font>
# </p>

# %%
# TO-DO: create `nominal_df` according to above explanations
nominal_df = None
nominal_df.head()

# %%
# تبدیل ستون‌های اسمی به one-hot encoding
nominal_df = pd.get_dummies(df[nominal_cols], prefix=nominal_cols)
nominal_df.head()

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# قسمت پنجم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# در قسمت پنجم از شما می‌خواهیم دیتافریمی داشته باشید که فقط شامل ستون‌های ترتیبی دیتافریم <code>df</code> باشد. سپس همه مقادیر دیتافریم جدید را به عدد تبدیل کنید.
# <br>
# با استفاده از <code>ordinal_cols</code> دیتافریم <code>ordinal_df</code>   را بسازید.
# همانند کاری که در قسمت سوم برای ستون‌های دودویی کردید، این بار برای ستون‌های ترتیبی هم انجام دهید. یعنی با استفاده از جدول تبدیلات که در ابتدای تمرین آورده شد، مقادیر موجود در دیتافریم <code>ordinal_df</code> را به عدد تبدیل کنید.
# </font>
# </p>

# %%
# TO-DO: create `ordinal_df` accordiing to above explanations
ordinal_df = None
ordinal_df.head()

# %%
# ایجاد دیتافریم با ستون‌های ترتیبی
ordinal_df = df[ordinal_cols].copy()

# تبدیل education
education_mapping = {
    'illiterate': 0,
    'basic.4y': 1,
    'basic.6y': 2,
    'basic.9y': 3,
    'high.school': 4,
    'professional.course': 5,
    'university.degree': 6
}

# تبدیل day_of_week
day_mapping = {
    'mon': 0, 'tue': 1, 'wed': 2, 'thu': 3,
    'fri': 4, 'sat': 5, 'sun': 6
}

# تبدیل month
month_mapping = {
    'jan': 0, 'feb': 1, 'mar': 2, 'apr': 3,
    'may': 4, 'jun': 5, 'jul': 6, 'aug': 7,
    'sep': 8, 'oct': 9, 'nov': 10, 'dec': 11
}

ordinal_df['education'] = ordinal_df['education'].map(education_mapping)
ordinal_df['day_of_week'] = ordinal_df['day_of_week'].map(day_mapping)
ordinal_df['month'] = ordinal_df['month'].map(month_mapping)

# %%
# ایجاد دیتافریم نهایی
final_df = pd.concat([
    df[continuous_cols],
    binary_df,
    nominal_df,
    ordinal_df
], axis=1)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

joblib.dump(categorical_cols, "categorical_cols")
joblib.dump(continuous_cols, "continuous_cols")
joblib.dump(binary_cols, "binary_cols")
joblib.dump(nominal_cols, "nominal_cols")
joblib.dump(ordinal_cols, "ordinal_cols")

binary_df.to_csv('binary_df.csv', index=False)
nominal_df.to_csv('nominal_df.csv', index=False)
ordinal_df.to_csv('ordinal_df.csv', index=False)

df.to_csv('df.csv', index=False)

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ["categorical_cols", "continuous_cols", "binary_cols", "nominal_cols", "ordinal_cols", \
              "binary_df.csv", "nominal_df.csv", "ordinal_df.csv", "df.csv", "bank_marketing.ipynb"]
compress(file_names)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#     حال که سوالات را حل کردید، پیشنهاد می‌کنیم مجدداً روی مجموعه‌داده جدیدی که به دست آوردید، مدل‌سازی کنید تا تاثیر پیش‌پردازش را در نتیجه نهایی مشاهده کنید.
#     برای انجام مدل‌سازی دوباره، کافیست سلول زیر را اجرا کنید.
#     اگر اجرای این سلول با شکست مواجه شد، می‌تواند به یکی از دلایل زیر باشد.
#     <ul dir=rtl>
#         <li>
#             کتابخانه‌ی Fast Auto ML را نصب نکرده باشید.
#         </li>
#         <li>
#            پیش‌پردازش‌های توضیح داده‌شده را اشتباه انجام داده باشید.
#         </li>
#     </ul>
# </font>
# </p>

# %%
target_variable = 'y'
new_df = df[continuous_cols].join([binary_df, nominal_df, ordinal_df])

model = AutoML(task='classification', time_budget=120, verbose=0, estimator_list=['lgbm', 'rf'])
model.fit(new_df, df[target_variable])

df_test = new_df.join(df.y).sample(frac=0.3, random_state=313)
y_pred = model.predict(df_test.drop(target_variable, axis=1))

f1score = f1_score(df_test[target_variable], y_pred, pos_label='yes')*100
print(f'performance of model is {f1score} %')

# %%
import pandas as pd
from flaml import AutoML
from sklearn.metrics import f1_score

# خواندن داده‌ها
df = pd.read_csv('bank-additional-full.csv', na_values='unknown')

# تعریف لیست ستون‌های دسته‌ای (10 ستون)
categorical_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan',
                   'is_telephone_contact', 'month', 'day_of_week', 'poutcome']

# پر کردن مقادیر گمشده
df = df.fillna({
    'job': df["job"].mode()[0],
    'education': df["education"].mode()[0],
    'marital': df["marital"].mode()[0],
    'default': df["default"].mode()[0],
    'housing': df["housing"].mode()[0],
    'loan': df["loan"].mode()[0]
})

# تعریف انواع ستون‌ها
continuous_cols = ['age', 'duration', 'campaign', 'pdays', 'previous']
binary_cols = ['default', 'housing', 'loan', 'is_telephone_contact']
nominal_cols = ['job', 'marital']
ordinal_cols = ['education', 'month', 'day_of_week', 'poutcome']

# ساخت binary_df با کپی
binary_df = df[binary_cols].copy()
binary_df['default'] = binary_df['default'].map({'no': 0, 'yes': 1})
binary_df['housing'] = binary_df['housing'].map({'no': 0, 'yes': 1})
binary_df['loan'] = binary_df['loan'].map({'no': 0, 'yes': 1})
binary_df['is_telephone_contact'] = binary_df['is_telephone_contact'].map({'no': 0, 'yes': 1})

binary_df['default'] = binary_df['default'].astype(int)
binary_df['housing'] = binary_df['housing'].astype(int)
binary_df['loan'] = binary_df['loan'].astype(int)

# ساخت nominal_df
nominal_df = pd.get_dummies(df[nominal_cols])

# ساخت ordinal_df با کپی
ordinal_df = df[ordinal_cols].copy()
ordinal_df['poutcome'] = ordinal_df['poutcome'].map({'failure': -1, 'nonexistent': 0, 'success': 1})
ordinal_df['education'] = ordinal_df['education'].map({
    'illiterate': 0, 'basic.4y': 1, 'basic.6y': 2, 'basic.9y': 3,
    'high.school': 4, 'professional.course': 5, 'university.degree': 6
})
ordinal_df['month'] = ordinal_df['month'].map({
    'feb': 0, 'jan': 1, 'mar': 2, 'apr': 3, 'may': 4, 'jun': 5,
    'jul': 6, 'aug': 7, 'sep': 8, 'oct': 9, 'nov': 10, 'dec': 11
})
ordinal_df['day_of_week'] = ordinal_df['day_of_week'].map({
    'mon': 0, 'tue': 1, 'wed': 2, 'thu': 3, 'fri': 4, 'sat': 5, 'sun': 6
})

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
# می‌توانید تلاش کنید تا با انجام پیش‌پردازش‌های بیشتر، عملکرد مدل را بیشتر هم تقویت کنید!
# </font>
# </p>
